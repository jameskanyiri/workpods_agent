# %%
from geopy.geocoders import Nominatim

geolocator = Nominatim(user_agent="geo_app")
location = geolocator.geocode("Democratic Republic of the Congo, Goma")

print(location.latitude, location.longitude)
# Out:
# -1.6665685 29.225652
