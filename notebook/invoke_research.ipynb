# %%
import sys
from pathlib import Path

# Add project root to Python path
sys.path.insert(0, str(Path.cwd().parent))

from src.research_supervisor.supervisor import supervisor_agent
from langchain_core.messages import HumanMessage


research_topic = """

Best practice siting and GIS screening methodology for utility-scale PV in Uganda: how to apply parcel size, slope, buffer from water bodies, protected area exclusion, and grid proximity (Namanve 132 kV, 10 km) filters. Include relevant geospatial datasets and workflow.

"""

result = await supervisor_agent.ainvoke(
    {
        "supervisor_messages": [HumanMessage(content=research_topic)],
        "research_brief": research_topic,
    }
)

result
# Out:
# Starting Tavily search for query: 'Best-practice GIS methodology for siting utility-scale solar PV plants in Africa, including parcel size, slope, water body buffers, protected area exclusion, and grid proximity'
# Searching for: Best-practice GIS methodology for siting utility-scale solar PV plants in Africa, including parcel size, slope, water body buffers, protected area exclusion, and grid proximity
# Found 3 results for query: Best-practice GIS methodology for siting utility-scale solar PV plants in Africa, including parcel size, slope, water body buffers, protected area exclusion, and grid proximity
# Found 3 unique results
# Tavily search completed successfully
