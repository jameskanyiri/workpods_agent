# %%
site_evaluation_result = {
    "country": "CD",
    "country_parameters": None,
    "data_sources": {
        "biodiversity": {
            "citation": "GBIF.org (2024). GBIF Occurrence Download. https://doi.org/10.15468/dl.xxxxx",
            "description": "Global Biodiversity Information Facility - species occurrence data",
            "license": "CC0 / CC BY / CC BY-NC",
            "name": "GBIF",
            "url": "https://www.gbif.org/",
            "version": "Current",
        },
        "financial_parameters": {
            "citation": "Various sources including national energy regulators, central banks, and development finance institutions",
            "description": "Tax rates, electricity tariffs, and financial parameters from national regulatory authorities and development banks",
            "license": "Public domain / fair use",
            "name": "Country-Specific Financial Data",
            "url": None,
            "version": "2024",
        },
        "geocoding": {
            "citation": "OpenStreetMap contributors (2024). OpenStreetMap. Available at: https://www.openstreetmap.org/",
            "description": "Geographic data and reverse geocoding services",
            "license": "ODbL 1.0",
            "name": "OpenStreetMap / Nominatim",
            "url": "https://www.openstreetmap.org/",
            "version": "Current",
        },
        "protected_areas": {
            "citation": "UNEP-WCMC and IUCN (2024). Protected Planet: The World Database on Protected Areas (WDPA). Cambridge, UK: UNEP-WCMC and IUCN. Available at: www.protectedplanet.net",
            "description": "World Database on Protected Areas",
            "license": "CC BY 4.0",
            "name": "Protected Planet / WDPA",
            "url": "https://www.protectedplanet.net/",
            "version": "Current",
        },
        "socioeconomic_data": {
            "citation": "Meta Data for Good (2024). Distributed Renewable Energy Atlas. Available at: https://www.atlasdre.org/",
            "description": "Distributed Renewable Energy Atlas - settlement-level socioeconomic and infrastructure data",
            "license": "CC BY-NC 4.0",
            "name": "DRE Atlas / Meta Data for Good",
            "url": "https://www.atlasdre.org/",
            "version": "2024",
        },
        "technical_model": {
            "citation": "NREL (2024). System Advisor Model Version 2024.3.6. National Renewable Energy Laboratory. Golden, CO. Available at: https://sam.nrel.gov/",
            "description": "NREL's System Advisor Model via PySAM for technical and financial modeling",
            "license": "BSD 3-Clause",
            "name": "PVWatts / System Advisor Model (SAM)",
            "url": "https://sam.nrel.gov/",
            "version": "PySAM 5.1.0",
        },
        "weather_data": {
            "citation": "European Commission, Joint Research Centre (JRC) (2024). PVGIS Online Tool. Available at: https://re.jrc.ec.europa.eu/pvg_tools/en/",
            "description": "Photovoltaic Geographical Information System - TMY weather data and solar radiation",
            "license": "CC BY 4.0",
            "name": "PVGIS",
            "url": "https://re.jrc.ec.europa.eu/pvg_tools/en/",
            "version": "PVGIS 5.2",
        },
    },
    "evaluation_id": "20260120_124037",
    "financial": {
        "debt_amount_usd": 350000,
        "equity_investment_usd": 150000,
        "irr_pct": 64.19120801072967,
        "is_viable": True,
        "lcoe_usd_per_kwh": 0.059813867368411426,
        "npv_usd": 414135.38794278813,
        "payback_years": 1.6263883021895718,
        "risk_level": "Low",
        "total_capex_usd": 500000,
        "viability_score": 93,
    },
    "latitude": -1.685046,
    "longitude": 29.222949,
    "metadata": {
        "analysis_date": "2026-01-20T12:40:45.151759",
        "analyst": "AfCEN Solar Assessment API",
        "api_version": "1.0.0",
        "pipeline_version": "1.0.0",
    },
    "optimal_design": {
        "azimuth_deg": 101.86163187480597,
        "dc_ac_ratio": 1.3715932529174402,
        "iterations": 90,
        "metric_value": 15.58889517602397,
        "optimization_metric": "capacity_factor",
        "tilt_deg": 5.24865018187667,
    },
    "recommendations": [
        "Review detailed financial analysis",
        "Verify design parameters match site conditions",
    ],
    "request_id": "eval_20260120_124045",
    "socioeconomic_info": {
        "admin_level_1": "Nord-Kivu",
        "admin_level_2": "Goma",
        "ag_area": 1270.5,
        "ag_value": 785912,
        "agricultural_yield": 46605.4,
        "building_density_percent": 13.96,
        "closest_distance_water_km": 0,
        "crop_types": "plantain, bean, maize, cassava, rice",
        "demand_connection": 0.395,
        "demand_kwh": 67.1,
        "dist_main_road_km": 0.38,
        "dist_nearest_hub_km": 1.77,
        "distance_to_transmission_lines_km": 2.41,
        "fatalities_within_50km": "308:119:255:16",
        "has_education_facility": True,
        "has_health_facility": True,
        "has_nightlight": True,
        "hull_area": 0.078,
        "large_buildings": 10,
        "main_road_access": True,
        "mean_rwi": 1.3,
        "medium_buildings": 8,
        "nearest_hub_name": "Goma",
        "num_buildings": 170,
        "num_connections": 170,
        "num_education_facilities": 1,
        "num_health_facilities": 1,
        "population": 1132,
        "security_risk": "high",
        "small_buildings": 152,
        "very_small_structures": 18,
        "village_name": "Goma",
    },
    "system_capacity_kw": 500,
    "technical": {
        "ac_capacity_kw": 500,
        "annual_energy_kwh": 682793.6087098494,
        "capacity_factor_pct": 15.588895176023971,
        "dc_capacity_kw": 685.7966264587201,
        "specific_yield_kwh_per_kw": 1365.5872174196988,
        "weather_data_source": "PVGIS",
    },
    "timestamp": "2026-01-20T12:40:45.150803",
}

# %%
from google import genai
from PIL import Image

import os
from dotenv import load_dotenv

api_key = os.getenv("GEMINI_API_KEY")

client = genai.Client(api_key=api_key)

# Use the nano-banana-pro-preview model for image generation
model_id = "nano-banana-pro-preview"
prompt = "A high-fidelity image of a futuristic kitchen with a holographic interface"

response = client.models.generate_content(
    model=model_id,
    contents=[prompt],
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[1], line 15
#      12 model_id = "nano-banana-pro-preview"
#      13 prompt = "A high-fidelity image of a futuristic kitchen with a holographic interface"
# ---> 15 response = client.models.generate_content(
#      16     model=model_id,
#      17     contents=[prompt],
#      18 )
#
# File ~/BAYES/ADA/ada-platform-orchestrator-agent/.venv/lib/python3.13/site-packages/google/genai/models.py:5215, in Models.generate_content(self, model, contents, config)
#    5213 while remaining_remote_calls_afc > 0:
#    5214   i += 1
# -> 5215   response = self._generate_content(
#    5216       model=model, contents=contents, config=parsed_config
#    5217   )
#    5219   function_map = _extra_utils.get_function_map(parsed_config)
#    5220   if not function_map:
#
# ...

# %%
response.candidates[0].content.parts[0].inline_data
# Out:
# Blob(
#   data=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x01,\x01,\x00\x00\xff\xeb\x17eJP\x00\x01\x00\x00\x00\x01\x00\x00\x17[jumb\x00\x00\x00\x1ejumdc2pa\x00\x11\x00\x10\x80\x00\x00\xaa\x008\x9bq\x03c2pa\x00\x00\x00\x175jumb\x00\x00\x00Gjumdc2ma\x00\x11\x00\x10\x80\x00\x00...',
#   mime_type='image/jpeg'
# )

# %%
from IPython.display import Image, display

# Get the image data from the response
inline_data = response.candidates[0].content.parts[0].inline_data

# Display the image directly from bytes
display(Image(data=inline_data.data))

# %%
import base64

# Get the image data from the response
inline_data = response.candidates[0].content.parts[0].inline_data

# Convert bytes to base64 string
image_base64 = base64.b64encode(inline_data.data).decode('utf-8')

# Print info
print(f"MIME type: {inline_data.mime_type}")
print(f"Base64 length: {len(image_base64)} characters")
print(f"Base64 preview: {image_base64[:100]}...")
# Out:
# MIME type: image/jpeg
# Base64 length: 903940 characters
# Base64 preview: /9j/4AAQSkZJRgABAQEBLAEsAAD/6xdlSlAAAQAAAAEAABdbanVtYgAAAB5qdW1kYzJwYQARABCAAACqADibcQNjMnBhAAAAFzVq...
